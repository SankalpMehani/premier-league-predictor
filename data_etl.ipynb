# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json

# %%
def create_stats_table(soup):
    # Set General stats for every team
    pl_general_stats_table = soup.find("table", attrs={"id": "results2023-202491_overall"})
    general_stats = ['goals_for', 'goals_against', 'xg_for', 'xg_against']
    team_stats = {i.td.a.text:{} for i in pl_general_stats_table.tbody.find_all("tr")}
    for team_row in pl_general_stats_table.tbody.find_all("tr"):
        team_name = team_row.a.text
        for team_stat in team_row.find_all("td"):
            stat = team_stat.get('data-stat')         
            if stat in general_stats: 
                team_stats[team_name][stat] = team_stat.text

    # Set Shooting stats for every team
    pl_shooting_stats_table = soup.find("table", attrs={"id": "stats_squads_shooting_for"})
    shooting_stats = ['shots', 'shots_on_target', 'average_shot_distance', 'shots_free_kicks', 'pens_made', 'pens_att']
    for team_row in pl_shooting_stats_table.tbody.find_all("tr"):
        team_name = team_row.a.text
        for team_stat in team_row.find_all("td"):
            stat = team_stat.get('data-stat')
            if stat in shooting_stats: 
                team_stats[team_name][stat] = team_stat.text

    # Set Passing stats for every team
    pl_passing_stats_table = soup.find("table", attrs={"id": "stats_squads_passing_for"})
    passing_stats = ['passes_into_final_third', 'assisted_shots', 'passes_into_penalty_area', 'crosses_into_penalty_area', 'progressive_passes']
    for team_row in pl_passing_stats_table.tbody.find_all("tr"):
        team_name = team_row.a.text
        for team_stat in team_row.find_all("td"):
            stat = team_stat.get('data-stat')
            if stat in passing_stats: 
                team_stats[team_name][stat] = team_stat.text

    # Set Goal and Shot Creation stats for every team
    pl_gca_stats_table = soup.find("table", attrs={"id": "stats_squads_gca_for"})
    goal_creation_stats = ['sca']
    for team_row in pl_gca_stats_table.tbody.find_all("tr"):
        team_name = team_row.a.text
        for team_stat in team_row.find_all("td"):
            stat = team_stat.get('data-stat')
            if stat in goal_creation_stats: 
                team_stats[team_name][stat] = team_stat.text

    # Set Possession stats for every team
    pl_possession_stats_table = soup.find("table", attrs={"id": "stats_squads_possession_for"})
    possession_stats = ['possession', 'touches_att_3rd', 'touches_att_pen_area', 'progressive_passes_received']
    for team_row in pl_possession_stats_table.tbody.find_all("tr"):
        team_name = team_row.a.text
        for team_stat in team_row.find_all("td"):
            stat = team_stat.get('data-stat')
            if stat in possession_stats: 
                team_stats[team_name][stat] = team_stat.text


    return team_stats

# %%
# base_url = "https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats"
base_url = "https://fbref.com/en/comps/9/"

for year in range(2023, 2016, -1):
    url = base_url + f"{year}-{year+1}/{year}-{year+1}-Premier-League-Stats"
    data = requests.get(url)
    soup = BeautifulSoup(data.text)
    team_stats = create_stats_table(soup)
    break

print(json.dumps(team_stats, indent=2))
# Out:
# {
#   "Manchester City": {
#     "goals_for": "16",
#     "goals_against": "3",
#     "xg_for": "13.5",
#     "xg_against": "4.6",
#     "shots": "102",
#     "shots_on_target": "42",
#     "average_shot_distance": "16.4",
#     "shots_free_kicks": "5",
#     "pens_made": "1",
#     "pens_att": "2",
#     "assisted_shots": "86",
#     "passes_into_final_third": "282",
#     "passes_into_penalty_area": "71",
#     "crosses_into_penalty_area": "9",
#     "progressive_passes": "289",
#     "sca": "196",
#     "possession": "66.0",
#     "touches_att_3rd": "1264",
#     "touches_att_pen_area": "179",
#     "progressive_passes_received": "286"
#   },
#   "Liverpool": {
#     "goals_for": "15",
#     "goals_against": "5",
#     "xg_for": "13.2",
#     "xg_against": "7.0",
#     "shots": "101",
#     "shots_on_target": "29",
#     "average_shot_distance": "17.0",
#     "shots_free_kicks": "4",
#     "pens_made": "1",
#     "pens_att": "2",
#     "assisted_shots": "76",
#     "passes_into_final_third": "205",
#     "passes_into_penalty_area": "56",
#     "crosses_into_penalty_area": "7",
#     "progressive_passes": "286",
#     "sca": "183",
#     "possession": "55.2",
#     "touches_att_3rd": "1037",
#     "touches_att_pen_area": "188",
#     "progressive_passes_received": "282"
#   },
#   "Brighton": {
#     "goals_for": "18",
#     "goals_against": "8",
#     "xg_for": "12.5",
#     "xg_against": "9.9",
#     "shots": "105",
#     "shots_on_target": "47",
#     "average_shot_distance": "17.5",
#     "shots_free_kicks": "1",
#     "pens_made": "1",
#     "pens_att": "1",
#     "assisted_shots": "92",
#     "passes_into_final_third": "218",
#     "passes_into_penalty_area": "76",
#     "crosses_into_penalty_area": "16",
#     "progressive_passes": "303",
#     "sca": "194",
#     "possession": "62.3",
#     "touches_att_3rd": "1126",
#     "touches_att_pen_area": "207",
#     "progressive_passes_received": "301"
#   },
#   "Tottenham": {
#     "goals_for": "15",
#     "goals_against": "7",
#     "xg_for": "10.9",
#     "xg_against": "8.7",
#     "shots": "114",
#     "shots_on_target": "44",
#     "average_shot_distance": "17.0",
#     "shots_free_kicks": "1",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "85",
#     "passes_into_final_third": "250",
#     "passes_into_penalty_area": "77",
#     "crosses_into_penalty_area": "9",
#     "progressive_passes": "317",
#     "sca": "198",
#     "possession": "59.3",
#     "touches_att_3rd": "1269",
#     "touches_att_pen_area": "237",
#     "progressive_passes_received": "315"
#   },
#   "Arsenal": {
#     "goals_for": "11",
#     "goals_against": "6",
#     "xg_for": "11.1",
#     "xg_against": "5.5",
#     "shots": "88",
#     "shots_on_target": "31",
#     "average_shot_distance": "16.3",
#     "shots_free_kicks": "0",
#     "pens_made": "3",
#     "pens_att": "3",
#     "assisted_shots": "68",
#     "passes_into_final_third": "286",
#     "passes_into_penalty_area": "84",
#     "crosses_into_penalty_area": "12",
#     "progressive_passes": "328",
#     "sca": "164",
#     "possession": "63.0",
#     "touches_att_3rd": "1416",
#     "touches_att_pen_area": "212",
#     "progressive_passes_received": "322"
#   },
#   "Aston Villa": {
#     "goals_for": "12",
#     "goals_against": "10",
#     "xg_for": "11.9",
#     "xg_against": "9.6",
#     "shots": "83",
#     "shots_on_target": "32",
#     "average_shot_distance": "15.6",
#     "shots_free_kicks": "2",
#     "pens_made": "2",
#     "pens_att": "2",
#     "assisted_shots": "63",
#     "passes_into_final_third": "209",
#     "passes_into_penalty_area": "63",
#     "crosses_into_penalty_area": "15",
#     "progressive_passes": "232",
#     "sca": "142",
#     "possession": "50.2",
#     "touches_att_3rd": "851",
#     "touches_att_pen_area": "161",
#     "progressive_passes_received": "231"
#   },
#   "West Ham": {
#     "goals_for": "11",
#     "goals_against": "10",
#     "xg_for": "9.0",
#     "xg_against": "13.3",
#     "shots": "65",
#     "shots_on_target": "24",
#     "average_shot_distance": "15.2",
#     "shots_free_kicks": "0",
#     "pens_made": "1",
#     "pens_att": "1",
#     "assisted_shots": "49",
#     "passes_into_final_third": "115",
#     "passes_into_penalty_area": "29",
#     "crosses_into_penalty_area": "7",
#     "progressive_passes": "148",
#     "sca": "118",
#     "possession": "35.8",
#     "touches_att_3rd": "600",
#     "touches_att_pen_area": "119",
#     "progressive_passes_received": "148"
#   },
#   "Newcastle Utd": {
#     "goals_for": "16",
#     "goals_against": "7",
#     "xg_for": "12.1",
#     "xg_against": "6.4",
#     "shots": "86",
#     "shots_on_target": "39",
#     "average_shot_distance": "16.2",
#     "shots_free_kicks": "1",
#     "pens_made": "1",
#     "pens_att": "1",
#     "assisted_shots": "67",
#     "passes_into_final_third": "170",
#     "passes_into_penalty_area": "55",
#     "crosses_into_penalty_area": "9",
#     "progressive_passes": "227",
#     "sca": "153",
#     "possession": "51.7",
#     "touches_att_3rd": "873",
#     "touches_att_pen_area": "168",
#     "progressive_passes_received": "226"
#   },
#   "Manchester Utd": {
#     "goals_for": "7",
#     "goals_against": "10",
#     "xg_for": "9.9",
#     "xg_against": "10.2",
#     "shots": "89",
#     "shots_on_target": "26",
#     "average_shot_distance": "16.8",
#     "shots_free_kicks": "2",
#     "pens_made": "1",
#     "pens_att": "1",
#     "assisted_shots": "76",
#     "passes_into_final_third": "209",
#     "passes_into_penalty_area": "56",
#     "crosses_into_penalty_area": "3",
#     "progressive_passes": "266",
#     "sca": "162",
#     "possession": "48.3",
#     "touches_att_3rd": "1004",
#     "touches_att_pen_area": "152",
#     "progressive_passes_received": "263"
#   },
#   "Crystal Palace": {
#     "goals_for": "6",
#     "goals_against": "7",
#     "xg_for": "7.2",
#     "xg_against": "8.3",
#     "shots": "82",
#     "shots_on_target": "31",
#     "average_shot_distance": "16.8",
#     "shots_free_kicks": "5",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "64",
#     "passes_into_final_third": "174",
#     "passes_into_penalty_area": "49",
#     "crosses_into_penalty_area": "8",
#     "progressive_passes": "210",
#     "sca": "144",
#     "possession": "47.2",
#     "touches_att_3rd": "916",
#     "touches_att_pen_area": "142",
#     "progressive_passes_received": "206"
#   },
#   "Fulham": {
#     "goals_for": "5",
#     "goals_against": "10",
#     "xg_for": "5.4",
#     "xg_against": "13.1",
#     "shots": "56",
#     "shots_on_target": "18",
#     "average_shot_distance": "17.7",
#     "shots_free_kicks": "4",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "39",
#     "passes_into_final_third": "198",
#     "passes_into_penalty_area": "47",
#     "crosses_into_penalty_area": "11",
#     "progressive_passes": "217",
#     "sca": "95",
#     "possession": "50.0",
#     "touches_att_3rd": "774",
#     "touches_att_pen_area": "93",
#     "progressive_passes_received": "214"
#   },
#   "Nott'ham Forest": {
#     "goals_for": "7",
#     "goals_against": "9",
#     "xg_for": "6.3",
#     "xg_against": "8.3",
#     "shots": "62",
#     "shots_on_target": "20",
#     "average_shot_distance": "17.1",
#     "shots_free_kicks": "1",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "47",
#     "passes_into_final_third": "113",
#     "passes_into_penalty_area": "35",
#     "crosses_into_penalty_area": "4",
#     "progressive_passes": "159",
#     "sca": "113",
#     "possession": "36.7",
#     "touches_att_3rd": "684",
#     "touches_att_pen_area": "114",
#     "progressive_passes_received": "154"
#   },
#   "Brentford": {
#     "goals_for": "9",
#     "goals_against": "9",
#     "xg_for": "11.2",
#     "xg_against": "7.9",
#     "shots": "82",
#     "shots_on_target": "24",
#     "average_shot_distance": "14.8",
#     "shots_free_kicks": "3",
#     "pens_made": "2",
#     "pens_att": "2",
#     "assisted_shots": "56",
#     "passes_into_final_third": "155",
#     "passes_into_penalty_area": "52",
#     "crosses_into_penalty_area": "12",
#     "progressive_passes": "225",
#     "sca": "141",
#     "possession": "49.5",
#     "touches_att_3rd": "777",
#     "touches_att_pen_area": "171",
#     "progressive_passes_received": "225"
#   },
#   "Chelsea": {
#     "goals_for": "5",
#     "goals_against": "6",
#     "xg_for": "11.5",
#     "xg_against": "6.3",
#     "shots": "90",
#     "shots_on_target": "27",
#     "average_shot_distance": "15.9",
#     "shots_free_kicks": "5",
#     "pens_made": "0",
#     "pens_att": "1",
#     "assisted_shots": "64",
#     "passes_into_final_third": "272",
#     "passes_into_penalty_area": "80",
#     "crosses_into_penalty_area": "12",
#     "progressive_passes": "314",
#     "sca": "165",
#     "possession": "66.5",
#     "touches_att_3rd": "1339",
#     "touches_att_pen_area": "221",
#     "progressive_passes_received": "312"
#   },
#   "Everton": {
#     "goals_for": "5",
#     "goals_against": "10",
#     "xg_for": "9.4",
#     "xg_against": "8.7",
#     "shots": "85",
#     "shots_on_target": "31",
#     "average_shot_distance": "16.1",
#     "shots_free_kicks": "2",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "61",
#     "passes_into_final_third": "156",
#     "passes_into_penalty_area": "38",
#     "crosses_into_penalty_area": "9",
#     "progressive_passes": "175",
#     "sca": "141",
#     "possession": "42.0",
#     "touches_att_3rd": "859",
#     "touches_att_pen_area": "124",
#     "progressive_passes_received": "174"
#   },
#   "Wolves": {
#     "goals_for": "6",
#     "goals_against": "12",
#     "xg_for": "7.7",
#     "xg_against": "12.5",
#     "shots": "76",
#     "shots_on_target": "22",
#     "average_shot_distance": "16.1",
#     "shots_free_kicks": "1",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "58",
#     "passes_into_final_third": "139",
#     "passes_into_penalty_area": "42",
#     "crosses_into_penalty_area": "14",
#     "progressive_passes": "197",
#     "sca": "133",
#     "possession": "47.3",
#     "touches_att_3rd": "763",
#     "touches_att_pen_area": "137",
#     "progressive_passes_received": "196"
#   },
#   "Bournemouth": {
#     "goals_for": "5",
#     "goals_against": "11",
#     "xg_for": "7.5",
#     "xg_against": "12.8",
#     "shots": "75",
#     "shots_on_target": "25",
#     "average_shot_distance": "18.0",
#     "shots_free_kicks": "4",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "51",
#     "passes_into_final_third": "146",
#     "passes_into_penalty_area": "50",
#     "crosses_into_penalty_area": "9",
#     "progressive_passes": "190",
#     "sca": "130",
#     "possession": "42.8",
#     "touches_att_3rd": "802",
#     "touches_att_pen_area": "149",
#     "progressive_passes_received": "187"
#   },
#   "Luton Town": {
#     "goals_for": "3",
#     "goals_against": "11",
#     "xg_for": "6.5",
#     "xg_against": "8.8",
#     "shots": "61",
#     "shots_on_target": "9",
#     "average_shot_distance": "15.3",
#     "shots_free_kicks": "1",
#     "pens_made": "2",
#     "pens_att": "2",
#     "assisted_shots": "47",
#     "passes_into_final_third": "116",
#     "passes_into_penalty_area": "37",
#     "crosses_into_penalty_area": "13",
#     "progressive_passes": "166",
#     "sca": "115",
#     "possession": "36.4",
#     "touches_att_3rd": "680",
#     "touches_att_pen_area": "122",
#     "progressive_passes_received": "164"
#   },
#   "Burnley": {
#     "goals_for": "4",
#     "goals_against": "13",
#     "xg_for": "4.0",
#     "xg_against": "8.3",
#     "shots": "53",
#     "shots_on_target": "14",
#     "average_shot_distance": "17.2",
#     "shots_free_kicks": "1",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "39",
#     "passes_into_final_third": "123",
#     "passes_into_penalty_area": "31",
#     "crosses_into_penalty_area": "6",
#     "progressive_passes": "168",
#     "sca": "91",
#     "possession": "50.8",
#     "touches_att_3rd": "718",
#     "touches_att_pen_area": "101",
#     "progressive_passes_received": "165"
#   },
#   "Sheffield Utd": {
#     "goals_for": "5",
#     "goals_against": "17",
#     "xg_for": "4.5",
#     "xg_against": "15.3",
#     "shots": "50",
#     "shots_on_target": "18",
#     "average_shot_distance": "16.3",
#     "shots_free_kicks": "0",
#     "pens_made": "0",
#     "pens_att": "0",
#     "assisted_shots": "30",
#     "passes_into_final_third": "110",
#     "passes_into_penalty_area": "27",
#     "crosses_into_penalty_area": "6",
#     "progressive_passes": "121",
#     "sca": "77",
#     "possession": "36.8",
#     "touches_att_3rd": "559",
#     "touches_att_pen_area": "95",
#     "progressive_passes_received": "121"
#   }
# }

# %%
# Pass type stats

# "TB" - completed pass sent between back defenders into open space.

# Add this if you want

# %%
import json

print(json.dumps(team_stats, indent=2))
# Out:
# {
#   "Manchester City": {
#     "goals_for": "16",
#     "goals_against": "3",
#     "xg_for": "13.5",
#     "xg_against": "4.6"
#   },
#   "Liverpool": {
#     "goals_for": "15",
#     "goals_against": "5",
#     "xg_for": "13.2",
#     "xg_against": "7.0"
#   },
#   "Brighton": {
#     "goals_for": "18",
#     "goals_against": "8",
#     "xg_for": "12.5",
#     "xg_against": "9.9"
#   },
#   "Tottenham": {
#     "goals_for": "15",
#     "goals_against": "7",
#     "xg_for": "10.9",
#     "xg_against": "8.7"
#   },
#   "Arsenal": {
#     "goals_for": "11",
#     "goals_against": "6",
#     "xg_for": "11.1",
#     "xg_against": "5.5"
#   },
#   "Aston Villa": {
#     "goals_for": "12",
#     "goals_against": "10",
#     "xg_for": "11.9",
#     "xg_against": "9.6"
#   },
#   "West Ham": {
#     "goals_for": "11",
#     "goals_against": "10",
#     "xg_for": "9.0",
#     "xg_against": "13.3"
#   },
#   "Newcastle Utd": {
#     "goals_for": "16",
#     "goals_against": "7",
#     "xg_for": "12.1",
#     "xg_against": "6.4"
#   },
#   "Manchester Utd": {
#     "goals_for": "7",
#     "goals_against": "10",
#     "xg_for": "9.9",
#     "xg_against": "10.2"
#   },
#   "Crystal Palace": {
#     "goals_for": "6",
#     "goals_against": "7",
#     "xg_for": "7.2",
#     "xg_against": "8.3"
#   },
#   "Fulham": {
#     "goals_for": "5",
#     "goals_against": "10",
#     "xg_for": "5.4",
#     "xg_against": "13.1"
#   },
#   "Nott'ham Forest": {
#     "goals_for": "7",
#     "goals_against": "9",
#     "xg_for": "6.3",
#     "xg_against": "8.3"
#   },
#   "Brentford": {
#     "goals_for": "9",
#     "goals_against": "9",
#     "xg_for": "11.2",
#     "xg_against": "7.9"
#   },
#   "Chelsea": {
#     "goals_for": "5",
#     "goals_against": "6",
#     "xg_for": "11.5",
#     "xg_against": "6.3"
#   },
#   "Everton": {
#     "goals_for": "5",
#     "goals_against": "10",
#     "xg_for": "9.4",
#     "xg_against": "8.7"
#   },
#   "Wolves": {
#     "goals_for": "6",
#     "goals_against": "12",
#     "xg_for": "7.7",
#     "xg_against": "12.5"
#   },
#   "Bournemouth": {
#     "goals_for": "5",
#     "goals_against": "11",
#     "xg_for": "7.5",
#     "xg_against": "12.8"
#   },
#   "Luton Town": {
#     "goals_for": "3",
#     "goals_against": "11",
#     "xg_for": "6.5",
#     "xg_against": "8.8"
#   },
#   "Burnley": {
#     "goals_for": "4",
#     "goals_against": "13",
#     "xg_for": "4.0",
#     "xg_against": "8.3"
#   },
#   "Sheffield Utd": {
#     "goals_for": "5",
#     "goals_against": "17",
#     "xg_for": "4.5",
#     "xg_against": "15.3"
#   }
# }

# %%
df = pd.DataFrame(team_stats).transpose()
print(df)
# Out:
#                 games wins ties losses goals_for goals_against goal_diff  \
# Manchester City     6    6    0      0        16             3       +13
# Liverpool           6    5    1      0        15             5       +10
# Brighton            6    5    0      1        18             8       +10
# Tottenham           6    4    2      0        15             7        +8
# Arsenal             6    4    2      0        11             6        +5
# Aston Villa         6    4    0      2        12            10        +2
# West Ham            6    3    1      2        11            10        +1
# Newcastle Utd       6    3    0      3        16             7        +9
# Manchester Utd      6    3    0      3         7            10        -3
# Crystal Palace      6    2    2      2         6             7        -1
# Fulham              6    2    2      2         5            10        -5
# Nott'ham Forest     6    2    1      3         7             9        -2
# Brentford           6    1    3      2         9             9         0
# Chelsea             6    1    2      3         5             6        -1
# Everton             6    1    1      4         5            10        -5
# Wolves              6    1    1      4         6            12        -6
# Bournemouth         6    0    3      3         5            11        -6
# Luton Town          5    0    1      4         3            11        -8
# Burnley             5    0    1      4         4            13        -9
# Sheffield Utd       6    0    1      5         5            17       -12
#
#                 points points_avg
# Manchester City     18       3.00
# Liverpool           16       2.67
# Brighton            15       2.50
# Tottenham           14       2.33
# Arsenal             14       2.33
# Aston Villa         12       2.00
# West Ham            10       1.67
# Newcastle Utd        9       1.50
# Manchester Utd       9       1.50
# Crystal Palace       8       1.33
# Fulham               8       1.33
# Nott'ham Forest      7       1.17
# Brentford            6       1.00
# Chelsea              5       0.83
# Everton              4       0.67
# Wolves               4       0.67
# Bournemouth          3       0.50
# Luton Town           1       0.20
# Burnley              1       0.20
# Sheffield Utd        1       0.17
